# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikhRabia/ai-learning-lab/blob/main/notebooks/First%20Prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Prompt
#
# **Course:** AI Agents and Agentic AI with Python & Generative AI (Coursera)
#
# ## Objective
#
# Programmatically send prompts to an LLM using LiteLLM and Gemini, then build a multi-step workflow that generates, documents, and tests Python code.
#
# ## Environment
#
# - Platform: Google Colab
# - Language: Python
# - LLM Interface: LiteLLM
# - Model: Gemini
#
# ## Status
#
# 🟡 In Progress

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('GOOGLE_API_KEY')
os.environ['GOOGLE_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response."""
    response = completion(
        model="gemini/gemini-3-flash-preview",
        messages=messages,
        max_tokens=2048
    )
    return response.choices[0].message.content


def extract_python_code(response: str) -> str:
    """Extract Python code from an LLM response."""
    if "```python" in response:
        code = response.split("```python")[1].split("```")[0]
        return code.strip()

    if "```" in response:
        code = response.split("```")[1].split("```")[0]
        return code.strip()

    return response.strip()


function_request = input(
    "What Python function would you like to create? "
)

messages = [
    {
        "role": "system",
        "content": (
            "You are an expert Python developer. "
            "Write clear, beginner-friendly Python functions."
        )
    },
    {
        "role": "user",
        "content": function_request
    }
]

response = generate_response(messages)

generated_code = extract_python_code(response)

print("\nGenerated Python code:\n")
print(generated_code)

# Markdown Cell
## Prompt 2 — Add Documentation

# Code Cell
documentation_messages = [
    {
        "role": "system",
        "content": "You are an expert Python developer. Improve the provided Python function and add clear, comprehensive documentation."
    },
    {
        "role": "user",
        "content": f"""
Add comprehensive documentation to the following Python function.

Include:
- Function description
- Parameter descriptions
- Return value description
- Example usage
- Edge cases

Python function:

{generated_code}
"""
    }
]

documentation_response = generate_response(documentation_messages)

print("\nDocumented Function:\n")
print(documentation_response)
# Out:
# What Python function would you like to create? Create a function that checks if a number is even or odd.
#
# Generated Python code:
#
# def check_even_odd(number):
#     """
#     Checks if a number is even or odd.
#
#     Args:
#         number (int): The number to check.
#
#     Returns:
#         str: "Even" if the number is even, "Odd" if it is odd.
#     """
#     if number % 2 == 0:
#         return "Even"
#     else:
#         return "Odd"
#
# # --- Testing the function ---
# num1 = 10
# num2 = 7
#
# print(f"{num1} is {check_even_odd(num1)}")
# print(f"{num2} is {check_even_odd(num2)}")
#
# Documented Function:
#
# To improve the function, I have added **type hinting**, a **guard clause** to ensure the input is an integer, and a more Pythonic **conditional expression** (ternary operator). The documentation follows the **Google Style** Python docstring format, which is widely considered the industry standard for clarity.
#
# ### Improved Function with Documentation
#
# ```python
# def check_even_odd(number: int) -> str:
#     """
#     Determines whether a given integer is even or odd.
#
#     This function evaluates the parity of an integer. Parity is the property
#     of an integer's inclusion in one of two categories: even (divisible by 2)
#     or odd (not divisible by 2).
#
#     Args:
#         number (int): The integer value to evaluate.
#
#     Returns:
#         str: Returns "Even" if the number is divisible by 2 (e.g., 0, 2, -4).
#              Returns "Odd" if the number is not divisible by 2 (e.g., 1, 3, -7).
#
#     Raises:
#         TypeError: If the input provided is not an integer.
#
#     Example:
#         >>> check_even_odd(10)
#         'Even'
#         >>> check_even_odd(7)
#         'Odd'
#         >>> check_even_odd(-2)
#         'Even'
#         >>> check_even_odd(0)
#         'Even'
#
#     Edge Cases & Behavior:
#         - **Zero (0):** Mathematically, zero is an even number because 0 / 2
#           leaves a remainder of 0. This function correctly returns "Even".
#         - **Negative Numbers:** The function handles negative integers correctly
#           (e.g., -1 is "Odd", -2 is "Even").
#         - **Floating Point Numbers:** If a float is passed (e.g., 2.0), the
#           function will raise a TypeError to prevent logical errors, as parity
#           is traditionally defined for integers only.
#         - **Non-numeric Types:** Passing strings, lists, or None will result in
#           a TypeError.
#     """
#     if not isinstance(number, int):
#         raise TypeError(f"Expected integer input, but received {type(number).__name__}.")
#
#     return "Even" if number % 2 == 0 else "Odd"
#
#
# # --- Testing the improved function ---
# if __name__ == "__main__":
#     try:
#         test_numbers = [10, 7, 0, -3, -4]
#
#         for num in test_numbers:
#             print(f"The number {num: >2} is: {check_even_odd(num)}")
#
#         # Example of handling an edge case (wrong type)
#         # check_even_odd(2.5)  # This would raise a TypeError
#
#     except TypeError as e:
#         print(f"Error: {e}")
# ```
#
# ### Key Improvements Made:
#
# 1.  **Type Hinting (`number: int -> str`):** Provides immediate feedback to developers and IDEs about what data types are expected and returned.
# 2.  **Input Validation:** Added `isinstance(number, int)`. In the original version, passing a float like `2.5` would have returned `"Odd"` because `2.5 % 2` is `0.5` (not `0`). Since parity is an integer concept, it is safer to enforce integer inputs.
# 3.  **Ternary Operator:** Used `return "Even" if ... else "Odd"` to make the code more concise and readable (standard "Pythonic" style).
# 4.  **Comprehensive Docstring:**
#     *   **Description:** Explains the math behind the function.
#     *   **Args/Returns:** Clearly defines the interface.
#     *   **Raises:** Documents potential errors.
#     *   **Edge Cases:** Explicitly explains how the function handles zero, negative numbers, and invalid types.
# 5.  **Main Guard (`if __name__ == "__main__":`):** Wrapped the test code so that it only runs when the script is executed directly, and not when the function is imported into another file.

# %%
documentation_messages = [
    {
        "role": "system",
        "content": "You are an expert Python developer. Improve the provided Python function and add clear, comprehensive documentation."
    },
    {
        "role": "user",
        "content": f"""
Add comprehensive documentation to the following Python function.

Include:
- Function description
- Parameter descriptions
- Return value description
- Example usage
- Edge cases

Python function:

{generated_code}
"""
    }
]

documentation_response = generate_response(documentation_messages)

print("\nDocumented Function:\n")
print(documentation_response)

documented_code = extract_python_code(documentation_response)

print("\nExtracted Documented Code:\n")
print(documented_code)
# Out:
# Documented Function:
#
# To improve the function, I have added **type hinting**, **input validation** to ensure the function only processes integers, and a **ternary operator** for cleaner syntax. The documentation follows the **Google Style** docstring format, which is a standard in the Python community for clarity.
#
# ### Improved Python Function
#
# ```python
# from typing import Union
#
# def check_even_odd(number: int) -> str:
#     """
#     Determines whether a given integer is even or odd.
#
#     The function checks the parity of an integer using the modulo operator (%).
#     An even number is any integer that is exactly divisible by 2, whereas
#     an odd number leaves a remainder of 1.
#
#     Args:
#         number (int): The integer value to be evaluated.
#
#     Returns:
#         str: Returns "Even" if the number is divisible by 2, otherwise returns "Odd".
#
#     Raises:
#         TypeError: If the input provided is not an integer.
#
#     Examples:
#         >>> check_even_odd(10)
#         'Even'
#         >>> check_even_odd(7)
#         'Odd'
#         >>> check_even_odd(-42)
#         'Even'
#         >>> check_even_odd(0)
#         'Even'
#
#     Edge Cases:
#         - **Zero (0):** Mathematically, zero is an even number. The function correctly returns "Even".
#         - **Negative Numbers:** Parity applies to negative integers. For example, -3 is "Odd" and -4 is "Even".
#         - **Non-Integer Types:** If a float, string, or None is passed, the function raises a TypeError
#           to prevent logical errors in calculations.
#     """
#     # Validation: Ensure the input is an integer
#     if not isinstance(number, int):
#         raise TypeError(f"Input must be an integer. Received: {type(number).__name__}")
#
#     return "Even" if number % 2 == 0 else "Odd"
#
# # --- Testing the function ---
# if __name__ == "__main__":
#     test_cases = [10, 7, 0, -11, -24]
#
#     for val in test_cases:
#         print(f"Number: {val:>3} | Result: {check_even_odd(val)}")
#
#     # Example of handling an edge case (Wrong Type)
#     try:
#         check_even_odd(10.5)
#     except TypeError as e:
#         print(f"\nCaught expected error: {e}")
# ```
#
# ### Key Improvements Explained:
#
# 1.  **Type Hinting (`number: int -> str`):** This provides immediate feedback to developers and IDEs about what data types are expected and returned.
# 2.  **Input Validation:** The original function would allow a `float` (like `10.5`) to return "Odd" because `10.5 % 2` is `0.5`, which is not `0`. However, parity is technically a property of **integers**. Adding `isinstance(number, int)` ensures mathematical correctness.
# 3.  **Ternary Operator:** `return "Even" if ... else "Odd"` is more idiomatic and concise for simple conditional assignments in Python.
# 4.  **Google Style Docstrings:**
#     *   **Description:** Explains the "how" and "why."
#     *   **Args/Returns:** Clearly defines the interface.
#     *   **Raises:** Documents potential crashes so the caller can handle them.
#     *   **Examples:** Allows for "doctest" compatibility and quick visual reference.
#     *   **Edge Cases:** Addresses specific concerns like negative numbers and zero.
# 5.  **Defensive Programming:** Using `if __name__ == "__main__":` ensures that the test code only runs when the script is executed directly, not when the function is imported into another file.
#
# Extracted Documented Code:
#
# from typing import Union
#
# def check_even_odd(number: int) -> str:
#     """
#     Determines whether a given integer is even or odd.
#
#     The function checks the parity of an integer using the modulo operator (%).
#     An even number is any integer that is exactly divisible by 2, whereas
#     an odd number leaves a remainder of 1.
#
#     Args:
#         number (int): The integer value to be evaluated.
#
#     Returns:
#         str: Returns "Even" if the number is divisible by 2, otherwise returns "Odd".
#
#     Raises:
#         TypeError: If the input provided is not an integer.
#
#     Examples:
#         >>> check_even_odd(10)
#         'Even'
#         >>> check_even_odd(7)
#         'Odd'
#         >>> check_even_odd(-42)
#         'Even'
#         >>> check_even_odd(0)
#         'Even'
#
#     Edge Cases:
#         - **Zero (0):** Mathematically, zero is an even number. The function correctly returns "Even".
#         - **Negative Numbers:** Parity applies to negative integers. For example, -3 is "Odd" and -4 is "Even".
#         - **Non-Integer Types:** If a float, string, or None is passed, the function raises a TypeError
#           to prevent logical errors in calculations.
#     """
#     # Validation: Ensure the input is an integer
#     if not isinstance(number, int):
#         raise TypeError(f"Input must be an integer. Received: {type(number).__name__}")
#
#     return "Even" if number % 2 == 0 else "Odd"
#
# # --- Testing the function ---
# if __name__ == "__main__":
#     test_cases = [10, 7, 0, -11, -24]
#
#     for val in test_cases:
#         print(f"Number: {val:>3} | Result: {check_even_odd(val)}")
#
#     # Example of handling an edge case (Wrong Type)
#     try:
#         check_even_odd(10.5)
#     except TypeError as e:
#         print(f"\nCaught expected error: {e}")
